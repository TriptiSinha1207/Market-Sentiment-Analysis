# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "#  Market Sentiment vs Trader Performance\n",
    "This notebook explores how Bitcoin market sentiment (Fear/Greed) impacts trader performance using historical trade data from Hyperliquid and sentiment classification from the Bitcoin Fear-Greed Index."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Imports\n",
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Load data\n",
    "trader_df = pd.read_csv('historical_data.csv')\n",
    "sentiment_df = pd.read_csv('fear_greed_index.csv')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Format date columns\n",
    "trader_df['Date'] = pd.to_datetime(trader_df['Timestamp IST'], format='%d-%m-%Y %H:%M').dt.date\n",
    "sentiment_df['Date'] = pd.to_datetime(sentiment_df['date']).dt.date\n",
    "sentiment_df['Sentiment'] = sentiment_df['classification'].apply(lambda x: 'Fear' if 'fear' in x.lower() else 'Greed')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Merge datasets\n",
    "merged_df = pd.merge(trader_df, sentiment_df[['Date', 'Sentiment']], on='Date', how='inner')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Handle missing or invalid columns\n",
    "merged_df['Closed PnL'] = pd.to_numeric(merged_df['Closed PnL'], errors='coerce')\n",
    "merged_df['Size USD'] = pd.to_numeric(merged_df['Size USD'], errors='coerce')\n",
    "if 'Leverage' in merged_df.columns:\n",
    "    merged_df['Leverage'] = pd.to_numeric(merged_df['Leverage'], errors='coerce').fillna(0)\n",
    "else:\n",
    "    merged_df['Leverage'] = 0"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Group and analyze\n",
    "sentiment_pnl = merged_df.groupby('Sentiment')['Closed PnL'].agg(['mean', 'median', 'sum', 'count'])\n",
    "sentiment_pnl"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Plot average PnL by sentiment\n",
    "plt.figure(figsize=(8, 5))\n",
    "sns.barplot(data=sentiment_pnl.reset_index(), x='Sentiment', y='mean', palette='coolwarm')\n",
    "plt.title('Average Closed PnL by Market Sentiment')\n",
    "plt.ylabel('Average Closed PnL')\n",
    "plt.grid(True)\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.8"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 13
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "#  Market Sentiment vs Trader Performance\n",
#       8     "This notebook explores how Bitcoin market sentiment (Fear/Greed) impacts trader performance using historical trade data from Hyperliquid and sentiment classification from the Bitcoin Fear-Greed Index."
#       9    ]
#      10   },
#      11   {
#      12    "cell_type": "code",
# ---> 13    "execution_count": null,
#      14    "metadata": {},
#      15    "outputs": [],
#      16    "source": [
#      17     "# Imports\n",
#      18     "import pandas as pd\n",
#      19     "import matplotlib.pyplot as plt\n",
#      20     "import seaborn as sns"
#      21    ]
#      22   },
#      23   {
#      24    "cell_type": "code",
#      25    "execution_count": null,
#      26    "metadata": {},
#      27    "outputs": [],
#      28    "source": [
#      29     "# Load data\n",
#      30     "trader_df = pd.read_csv('historical_data.csv')\n",
#      31     "sentiment_df = pd.read_csv('fear_greed_index.csv')"
#      32    ]
#      33   },
#      34   {
#      35    "cell_type": "code",
#      36    "execution_count": null,
#      37    "metadata": {},
#      38    "outputs": [],
#      39    "source": [
#      40     "# Format date columns\n",
#      41     "trader_df['Date'] = pd.to_datetime(trader_df['Timestamp IST'], format='%d-%m-%Y %H:%M').dt.date\n",
#      42     "sentiment_df['Date'] = pd.to_datetime(sentiment_df['date']).dt.date\n",
#      43     "sentiment_df['Sentiment'] = sentiment_df['classification'].apply(lambda x: 'Fear' if 'fear' in x.lower() else 'Greed')"
#      44    ]
#      45   },
#      46   {
#      47    "cell_type": "code",
#      48    "execution_count": null,
#      49    "metadata": {},
#      50    "outputs": [],
#      51    "source": [
#      52     "# Merge datasets\n",
#      53     "merged_df = pd.merge(trader_df, sentiment_df[['Date', 'Sentiment']], on='Date', how='inner')"
#      54    ]
#      55   },
#      56   {
#      57    "cell_type": "code",
#      58    "execution_count": null,
#      59    "metadata": {},
#      60    "outputs": [],
#      61    "source": [
#      62     "# Handle missing or invalid columns\n",
#      63     "merged_df['Closed PnL'] = pd.to_numeric(merged_df['Closed PnL'], errors='coerce')\n",
#      64     "merged_df['Size USD'] = pd.to_numeric(merged_df['Size USD'], errors='coerce')\n",
#      65     "if 'Leverage' in merged_df.columns:\n",
#      66     "    merged_df['Leverage'] = pd.to_numeric(merged_df['Leverage'], errors='coerce').fillna(0)\n",
#      67     "else:\n",
#      68     "    merged_df['Leverage'] = 0"
#      69    ]
#      70   },
#      71   {
#      72    "cell_type": "code",
#      73    "execution_count": null,
#      74    "metadata": {},
#      75    "outputs": [],
#      76    "source": [
#      77     "# Group and analyze\n",
#      78     "sentiment_pnl = merged_df.groupby('Sentiment')['Closed PnL'].agg(['mean', 'median', 'sum', 'count'])\n",
#      79     "sentiment_pnl"
#      80    ]
#      81   },
#      82   {
#      83    "cell_type": "code",
#      84    "execution_count": null,
#      85    "metadata": {},
#      86    "outputs": [],
#      87    "source": [
#      88     "# Plot average PnL by sentiment\n",
#      89     "plt.figure(figsize=(8, 5))\n",
#      90     "sns.barplot(data=sentiment_pnl.reset_index(), x='Sentiment', y='mean', palette='coolwarm')\n",
#      91     "plt.title('Average Closed PnL by Market Sentiment')\n",
#      92     "plt.ylabel('Average Closed PnL')\n",
#      93     "plt.grid(True)\n",
#      94     "plt.show()"
#      95    ]
#      96   }
#      97  ],
#      98  "metadata": {
#      99   "kernelspec": {
#     100    "display_name": "Python 3",
#     101    "language": "python",
#     102    "name": "python3"
#     103   },
#     104   "language_info": {
#     105    "name": "python",
#     106    "version": "3.8"
#     107   }
#     108  },
#     109  "nbformat": 4,
#     110  "nbformat_minor": 2
#     111 }
#
# NameError: name 'null' is not defined
